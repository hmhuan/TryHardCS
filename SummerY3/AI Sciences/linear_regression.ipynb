# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('.\datas\Boston.csv')
dataset.head(10)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm    age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# 5           6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3
# 6           7  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5
# 7           8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5
# 8           9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5
# 9          10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2
# 5  222     18.7  394.12   5.21  28.7
# 6  311     15.2  395.60  12.43  22.9
# 7  311     15.2  396.90  19.15  27.1
# 8  311     15.2  386.63  29.93  16.5
# 9  311     15.2  386.71  17.10  18.9

# %%
X = dataset.drop(['Unnamed: 0', 'medv'], axis = 1)
Y = dataset['medv']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, Y_train)
Y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# the coefficients
print("Coefficients: \n", lr.coef_)
# mean squared error
print('Mean squared error: {:.2f}'.format(mean_squared_error(Y_test,Y_pred)))
# var
print('Variance score: {:.2f}'.format(r2_score(Y_test, Y_pred)))
# Out:
# Coefficients:
#  [-1.17996126e-01  5.31598699e-02  6.46390625e-03  2.73952323e+00
#  -1.82752094e+01  3.50244220e+00 -4.14431073e-04 -1.62411828e+00
#   3.21321539e-01 -1.03825591e-02 -9.19913256e-01  1.09791803e-02
#  -5.55019230e-01]
# Mean squared error: 19.69
# Variance score: 0.76

# %%
plt.scatter(Y_test,Y_pred) 
plt.xlabel("Prices: $Y_i$") 
plt.ylabel("Predicted prices: $\hat{Y}_i$") 
plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
# Out:
# Text(0.5, 1.0, 'Prices vs Predicted prices: $Y_i$ vs $\\hat{Y}_i$')
